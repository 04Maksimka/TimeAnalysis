# %% [raw]
# ---
# title: "Example: First Time Series Exploration"
# description: "A minimal notebook showing the metadata and saved outputs expected by the research blog."
# author: "TimeAnalysis Team"
# date: "2026-06-02"
# categories: [example, time-series]
# ---

# %% [markdown]
# ## Purpose
#
# Use this notebook as a template for a new research post. Execute the cells locally before committing the file so the published article includes the latest outputs.

# %%
values = [8, 11, 13, 14, 16]
{"observations": len(values), "average": sum(values) / len(values)}
# Out:
# {'observations': 5, 'average': 12.4}
